-- %%
SELECT * 
FROM employees_db;

SELECT * DISTINCT
FROM employees_db;

SELECT first_name,
      second_name 
FROM employees_db
ORDER BY salary DESC;

SELECT *
FROM employees_db
LIMIT 5;

SELECT *
FROM eployees_db
WHERE department='IT';

SELECT *
FROM employees_db
WHERE department = 'Finance' AND salary>58000;

SELECT *
FROM employees_db
WHERE department = 'HR' OR department='Marketing';

SELECT *
FROM employees_db
WHERE NOT department = 'IT';

SELECT *
FROM employees_db
WHERE department IN ('HR','IT','Finance');

SELECT first_name,
      last_name
FROM employees_db
WHERE department = 'Finance' OR department = 'Marketing' AND salary>52000
ORDER BY salary DESC;

SELECT DISTINCT
FROM employees_db
WHERE department IN ('FINANCE','MARKETING ');

SELECT *
FROM employees_db
WHERE NOT department= 'Finance' AND salary>50000 
ORDER BY hire_date ASC;

SELECT *
FROM employees_db
WHERE city IN ('Chicago','Los Angeles') AND department='IT' OR department='Marketing'
LIMIT 3;
